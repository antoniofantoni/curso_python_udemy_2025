# %%
import pandas as pd

# %%
df = pd.read_excel("tabela_campeonato.xlsx")
df
# Out:
#         Times  Partidas_jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0       Vasco               310         7        2         1        22
# 1    Cruzeiro                10         6        1         3        16
# 2   Palmeiras                10         5        3         2        18
# 3  Fluminense                10         4        3         3        14
# 4    Botafogo                10         3        2         5        10
#
#    Gols_sofridos  Saldo_gols  Pontos
# 0             10          12      23
# 1             15           1      19
# 2             12           6      18
# 3             16          -2      15
# 4             20         -10      11

# %%
# desempenho dos times
desempenho = df[['Times', 'Pontos']]
desempenho
# Out:
#         Times  Pontos
# 0       Vasco      23
# 1    Cruzeiro      19
# 2   Palmeiras      18
# 3  Fluminense      15
# 4    Botafogo      11

# %%
#time com mais vitorias
mais_vitorias = df[df['Vitorias'] == df['Vitorias'].max()]
mais_vitorias
# Out:
#    Times  Partidas_jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0  Vasco               310         7        2         1        22
#
#    Gols_sofridos  Saldo_gols  Pontos
# 0             10          12      23

# %%
# time com menos vitorias
menos_vitorias = df[df['Vitorias'] == df['Vitorias'].min()]
menos_vitorias
# Out:
#       Times  Partidas_jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 4  Botafogo                10         3        2         5        10
#
#    Gols_sofridos  Saldo_gols  Pontos
# 4             20         -10      11

# %%
#Time com mais derrotas
menos_vitorias = df[df['Derrotas'] == df['Derrotas'].max()]
menos_vitorias
# Out:
#       Times  Partidas_jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 4  Botafogo                10         3        2         5        10
#
#    Gols_sofridos  Saldo_gols  Pontos
# 4             20         -10      11

# %%
#time com menos empates
menos_empates = df[df['Empates'] == df['Empates'].min()]
menos_empates
# Out:
#       Times  Partidas_jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 1  Cruzeiro                10         6        1         3        16
#
#    Gols_sofridos  Saldo_gols  Pontos
# 1             15           1      19

# %%
gols_pro = df[['Times', 'Gols_Pro']] 
gols_pro
# Out:
#         Times  Gols_Pro
# 0       Vasco        22
# 1    Cruzeiro        16
# 2   Palmeiras        18
# 3  Fluminense        14
# 4    Botafogo        10

# %%
df['Gols_Pro'].value_counts()
# Out:
# Gols_Pro
# 22    1
# 16    1
# 18    1
# 14    1
# 10    1
# Name: count, dtype: int64

# %%
desempenho = df[['Times', 'Pontos', 'Vitorias', 'Derrotas', 'Gols_Pro']].set_index('Times')
desempenho
# Out:
#             Pontos  Vitorias  Derrotas  Gols_Pro
# Times
# Vasco           23         7         1        22
# Cruzeiro        19         6         3        16
# Palmeiras       18         5         2        18
# Fluminense      15         4         3        14
# Botafogo        11         3         5        10
